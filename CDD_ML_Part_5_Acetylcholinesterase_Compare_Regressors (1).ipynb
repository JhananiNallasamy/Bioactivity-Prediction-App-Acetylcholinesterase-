# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
#
# In this Jupyter notebook, we will be building a real-life data science project. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In this part, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (0.2.12)
# Requirement already satisfied: click in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (1.5.1)
# Requirement already satisfied: pandas in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (4.66.4)
# Requirement already satisfied: joblib in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (4.4.0)
# Requirement already satisfied: xgboost in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lazypredict) (2.1.0)
# Requirement already satisfied: colorama in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from click->lazypredict) (0.4.6)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from lightgbm->lazypredict) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)

# %%
! pip install scikit-learn
! pip install seaborn

import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: seaborn in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jhana\onedrive\desktop\drug discovery\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
import requests

url = 'https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv'
filename = 'acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv'

response = requests.get(url)
response.raise_for_status()  # Check if the request was successful

with open(filename, 'wb') as file:
    file.write(response.content)

print(f"Downloaded {filename} successfully.")
# Out:
# Downloaded acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv successfully.

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
#  98%|█████████▊| 41/42 [01:42<00:01,  1.37s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003524 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 100%|██████████| 42/42 [01:43<00:00,  2.46s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#  98%|█████████▊| 41/42 [01:44<00:01,  1.72s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004035 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 100%|██████████| 42/42 [01:45<00:00,  2.50s/it]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                        Adjusted R-Squared  \
# Model
# DecisionTreeRegressor                                0.86
# ExtraTreeRegressor                                   0.86
# ExtraTreesRegressor                                  0.86
# GaussianProcessRegressor                             0.86
# RandomForestRegressor                                0.82
# XGBRegressor                                         0.82
# BaggingRegressor                                     0.80
# MLPRegressor                                         0.76
# HistGradientBoostingRegressor                        0.67
# LGBMRegressor                                        0.65
# KNeighborsRegressor                                  0.63
# SVR                                                  0.56
# NuSVR                                                0.55
# GradientBoostingRegressor                            0.44
# Ridge                                                0.31
# LinearRegression                                     0.31
# TransformedTargetRegressor                           0.31
# LassoCV                                              0.30
# ElasticNetCV                                         0.30
# RidgeCV                                              0.30
# SGDRegressor                                         0.30
# BayesianRidge                                        0.29
# HuberRegressor                                       0.29
# LassoLarsCV                                          0.27
# LassoLarsIC                                          0.27
# LinearSVR                                            0.27
# PoissonRegressor                                     0.25
# AdaBoostRegressor                                    0.20
# OrthogonalMatchingPursuitCV                          0.20
# OrthogonalMatchingPursuit                            0.20
# TweedieRegressor                                     0.19
# GammaRegressor                                       0.19
# Lars                                                 0.15
# LarsCV                                               0.14
# LassoLars                                           -0.04
# ElasticNet                                          -0.04
# DummyRegressor                                      -0.04
# Lasso                                               -0.04
# QuantileRegressor                                   -0.05
# PassiveAggressiveRegressor                          -0.17
# KernelRidge                                        -14.25
# RANSACRegressor               -29752838899210301472768.00
#
#                                                 R-Squared            RMSE  \
# Model
# DecisionTreeRegressor                                0.86            0.57
# ExtraTreeRegressor                                   0.86            0.57
# ExtraTreesRegressor                                  0.86            0.57
# GaussianProcessRegressor                             0.86            0.57
# RandomForestRegressor                                0.83            0.64
# XGBRegressor                                         0.83            0.65
# BaggingRegressor                                     0.81            0.67
# MLPRegressor                                         0.77            0.75
# HistGradientBoostingRegressor                        0.69            0.87
# LGBMRegressor                                        0.67            0.90
# KNeighborsRegressor                                  0.65            0.92
# SVR                                                  0.58            1.01
# NuSVR                                                0.57            1.02
# GradientBoostingRegressor                            0.46            1.14
# Ridge                                                0.33            1.27
# LinearRegression                                     0.33            1.27
# TransformedTargetRegressor                           0.33            1.27
# LassoCV                                              0.33            1.27
# ElasticNetCV                                         0.33            1.27
# RidgeCV                                              0.33            1.27
# SGDRegressor                                         0.32            1.28
# BayesianRidge                                        0.32            1.28
# HuberRegressor                                       0.31            1.29
# LassoLarsCV                                          0.30            1.30
# LassoLarsIC                                          0.30            1.30
# LinearSVR                                            0.30            1.30
# PoissonRegressor                                     0.28            1.32
# AdaBoostRegressor                                    0.23            1.36
# OrthogonalMatchingPursuitCV                          0.23            1.37
# OrthogonalMatchingPursuit                            0.23            1.37
# TweedieRegressor                                     0.22            1.37
# GammaRegressor                                       0.22            1.37
# Lars                                                 0.18            1.41
# LarsCV                                               0.17            1.41
# LassoLars                                            0.00            1.55
# ElasticNet                                           0.00            1.55
# DummyRegressor                                       0.00            1.55
# Lasso                                                0.00            1.55
# QuantileRegressor                                   -0.01            1.56
# PassiveAggressiveRegressor                          -0.13            1.65
# KernelRidge                                        -13.70            5.95
# RANSACRegressor               -28667315882115276472320.00 262854402405.10
#
#                                Time Taken
# Model
# DecisionTreeRegressor                0.16
# ExtraTreeRegressor                   0.18
# ExtraTreesRegressor                  7.63
# GaussianProcessRegressor             9.22
# RandomForestRegressor                6.34
# XGBRegressor                         0.31
# BaggingRegressor                     0.67
# MLPRegressor                        19.85
# HistGradientBoostingRegressor        3.51
# LGBMRegressor                        0.44
# KNeighborsRegressor                  0.70
# SVR                                  2.98
# NuSVR                                3.58
# GradientBoostingRegressor            3.70
# Ridge                                0.06
# LinearRegression                     0.14
# TransformedTargetRegressor           0.09
# LassoCV                              6.33
# ElasticNetCV                         3.78
# RidgeCV                              0.14
# SGDRegressor                         0.11
# BayesianRidge                        0.22
# HuberRegressor                       1.38
# LassoLarsCV                          1.10
# LassoLarsIC                          0.88
# LinearSVR                            1.24
# PoissonRegressor                     0.11
# AdaBoostRegressor                    1.62
# OrthogonalMatchingPursuitCV          0.15
# OrthogonalMatchingPursuit            0.08
# TweedieRegressor                     0.08
# GammaRegressor                       0.46
# Lars                                 0.44
# LarsCV                               1.03
# LassoLars                            0.18
# ElasticNet                           0.06
# DummyRegressor                       0.05
# Lasso                                0.15
# QuantileRegressor                    1.80
# PassiveAggressiveRegressor           0.08
# KernelRidge                          3.03
# RANSACRegressor                     19.04

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                        Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                        0.46
# RandomForestRegressor                                0.44
# LGBMRegressor                                        0.44
# XGBRegressor                                         0.44
# BaggingRegressor                                     0.41
# NuSVR                                                0.39
# SVR                                                  0.39
# KNeighborsRegressor                                  0.37
# MLPRegressor                                         0.36
# GradientBoostingRegressor                            0.33
# ExtraTreesRegressor                                  0.22
# DecisionTreeRegressor                                0.20
# TransformedTargetRegressor                           0.20
# LinearRegression                                     0.20
# Ridge                                                0.20
# RidgeCV                                              0.20
# ElasticNetCV                                         0.20
# LassoCV                                              0.20
# ExtraTreeRegressor                                   0.20
# SGDRegressor                                         0.19
# BayesianRidge                                        0.19
# HuberRegressor                                       0.19
# LassoLarsCV                                          0.18
# LassoLarsIC                                          0.18
# LinearSVR                                            0.16
# PoissonRegressor                                     0.16
# OrthogonalMatchingPursuit                            0.11
# OrthogonalMatchingPursuitCV                          0.11
# GammaRegressor                                       0.08
# TweedieRegressor                                     0.08
# AdaBoostRegressor                                    0.07
# LarsCV                                               0.03
# Lars                                                 0.01
# Lasso                                               -0.17
# ElasticNet                                          -0.17
# LassoLars                                           -0.17
# DummyRegressor                                      -0.17
# QuantileRegressor                                   -0.19
# PassiveAggressiveRegressor                          -0.42
# GaussianProcessRegressor                            -6.02
# KernelRidge                                        -16.36
# RANSACRegressor               -27576338802168270159872.00
#
#                                                 R-Squared            RMSE  \
# Model
# HistGradientBoostingRegressor                        0.54            1.06
# RandomForestRegressor                                0.52            1.08
# LGBMRegressor                                        0.52            1.08
# XGBRegressor                                         0.52            1.08
# BaggingRegressor                                     0.49            1.11
# NuSVR                                                0.48            1.12
# SVR                                                  0.48            1.12
# KNeighborsRegressor                                  0.46            1.14
# MLPRegressor                                         0.45            1.15
# GradientBoostingRegressor                            0.42            1.18
# ExtraTreesRegressor                                  0.34            1.27
# DecisionTreeRegressor                                0.32            1.28
# TransformedTargetRegressor                           0.32            1.28
# LinearRegression                                     0.32            1.28
# Ridge                                                0.32            1.28
# RidgeCV                                              0.32            1.28
# ElasticNetCV                                         0.32            1.28
# LassoCV                                              0.32            1.28
# ExtraTreeRegressor                                   0.32            1.29
# SGDRegressor                                         0.31            1.29
# BayesianRidge                                        0.31            1.29
# HuberRegressor                                       0.31            1.29
# LassoLarsCV                                          0.30            1.30
# LassoLarsIC                                          0.30            1.30
# LinearSVR                                            0.28            1.32
# PoissonRegressor                                     0.28            1.32
# OrthogonalMatchingPursuit                            0.24            1.36
# OrthogonalMatchingPursuitCV                          0.24            1.36
# GammaRegressor                                       0.22            1.37
# TweedieRegressor                                     0.22            1.38
# AdaBoostRegressor                                    0.21            1.38
# LarsCV                                               0.17            1.41
# Lars                                                 0.15            1.43
# Lasso                                               -0.00            1.55
# ElasticNet                                          -0.00            1.55
# LassoLars                                           -0.00            1.55
# DummyRegressor                                      -0.00            1.55
# QuantileRegressor                                   -0.02            1.57
# PassiveAggressiveRegressor                          -0.22            1.71
# GaussianProcessRegressor                            -4.99            3.80
# KernelRidge                                        -13.82            5.98
# RANSACRegressor               -23548664584794013696000.00 238334752524.88
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        1.43
# RandomForestRegressor                6.68
# LGBMRegressor                        0.40
# XGBRegressor                         0.29
# BaggingRegressor                     0.75
# NuSVR                                1.36
# SVR                                  2.19
# KNeighborsRegressor                  0.31
# MLPRegressor                        19.19
# GradientBoostingRegressor            2.43
# ExtraTreesRegressor                 10.05
# DecisionTreeRegressor                0.13
# TransformedTargetRegressor           0.11
# LinearRegression                     1.58
# Ridge                                0.05
# RidgeCV                              0.13
# ElasticNetCV                         3.84
# LassoCV                              5.57
# ExtraTreeRegressor                   0.12
# SGDRegressor                         0.09
# BayesianRidge                        0.15
# HuberRegressor                       1.29
# LassoLarsCV                          0.49
# LassoLarsIC                          1.49
# LinearSVR                            1.14
# PoissonRegressor                     0.26
# OrthogonalMatchingPursuit            0.06
# OrthogonalMatchingPursuitCV          0.19
# GammaRegressor                       0.08
# TweedieRegressor                     0.09
# AdaBoostRegressor                    1.81
# LarsCV                               1.00
# Lars                                 0.30
# Lasso                                0.13
# ElasticNet                           0.07
# LassoLars                            0.11
# DummyRegressor                       0.31
# QuantileRegressor                    1.41
# PassiveAggressiveRegressor           0.10
# GaussianProcessRegressor             4.85
# KernelRidge                          3.09
# RANSACRegressor                     29.84

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
